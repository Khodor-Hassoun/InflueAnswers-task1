# %%
import pandas as pd
import numpy as np

# %%
pd.read_csv("./chatlogs/uncleanData.csv")
# Out:
#       chat_date  chat_hour  chat_minute      user  \
# 0    2014-06-01         16           17    timbl_
# 1    2014-06-01         18           54    Lajjla
# 2    2014-06-01         20            4   ormaaj_
# 3    2014-06-01         20           46       wu_
# 4    2014-06-01         22           58       ix9
# ..          ...        ...          ...       ...
# 174  2014-06-04         21           37    danbri
# 175  2014-06-04         21           37  dc_swig_
# 176  2014-06-04         21           37    danbri
# 177  2014-06-04         21           37  dc_swig_
# 178  2014-06-04         21           42       ktk
#
#                         chat_message
# 0       timbl_ is now known as timbl
# 1    Lajjla is now known as PhallicQ
# 2     ormaaj_ is now known as ormaaj
# 3            wu_ is now known as ix9
# 4            ix9 is now known as wu_
# ..                               ...
# 174                       A:License?
# 175                Added comment A1.
# ...
